# %% [markdown]
# # CNN for Bottle Label Defects Classification
#
# This model is to build a CNN model that can classify bottle label based on their differences: without wrinkle or with wrinkle.
#
# The model used the following layers for all the steps:
#  - Conv2D: stride 2, padding is "SAME"
#  - BatchNormalization
#  - ReLU
#  - Flatten the previous output.
#  - SeparableConv2D
#  - Do not softmax. This will result in 6 neurons in the output layer, which then get passed later to a softmax.
#
# The model training includes the following items:
#     1. Hyper parameter optimization;
#     2. Number of layers test;
#     3. Training time and Run time test;
#     4. Test the minimum amount of images needed for a good model;
#     5. Test the minimum amount of sample bottles needed for a good model;
#     6. Test the minimum resolution of image needed for a good training.
#
#
# This structure is based on keras computer vision example.

# %%
# This will prompt for authorization.
from google.colab import drive
drive.mount('/content/drive')

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment3/'
FOLDERNAME = 'CS231N_Final_Project'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# This downloads the COCO dataset to your Drive
# if it doesn't already exist.
# %cd /content/drive/My\ Drive/$FOLDERNAME/cs231n/datasets/
# !bash get_datasets.sh
# %cd /content/drive/My\ Drive/$FOLDERNAME
# Out:
# Mounted at /content/drive
# [Errno 2] No such file or directory: '/content/drive/My Drive/CS231N_Final_Project/cs231n/datasets/'
# /content
# bash: get_datasets.sh: No such file or directory
# /content/drive/My Drive/CS231N_Final_Project

# %%
# TensorFlow 2.0 and keras environment

import numpy as np
import tensorflow as tf
from tensorflow import keras as K
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import time

# %%
# Hyper parameters and settings

# image size is related to the convnet size 180
image_size = (180, 180) 
# default batch norm size is 32, which is the best
batch_size = 32         # 16
# When the good bottle label background is consistent with some 
#   orientation variation, the epoch number can be 60.
# But when the good bottle label keep changing, then need epoch number to be 100.
epochs     = 100

# %%
# Generate a dataset

# Automatically randomly shuffle the images to train dataset and evaluation dataset.
# When there are some wrong images, the result can be very different due to this randomness.

train_dataset = K.preprocessing.image_dataset_from_directory(
    "WrinkleImages1",
    validation_split=0.2, # Randomly shuffle the dataset. 
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
val_dataset = K.preprocessing.image_dataset_from_directory(
    "WrinkleImages1",
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 500 files belonging to 2 classes.
# Using 400 files for training.
# Found 500 files belonging to 2 classes.
# Using 100 files for validation.

# %%
# Visualize the dataset

# class 0 - bad bottle label with wrinkle defects
# class 1 - good bottle label without wrinkle defects

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        #plt.imshow(images[1][1])
        plt.title(int(labels[i]))
        #plt.title(labels[train[0][1]])
        plt.axis("off")

# %%
# AUGMENTATION:
# - No need to rotate the image
# - Horizontal flip is helpful
# - rescaling
# - Randomzoom
# - resizing
data_augmentation = K.Sequential(
    [
        layers.experimental.preprocessing.RandomFlip("horizontal"),
        layers.experimental.preprocessing.RandomRotation(0),
    ]
)

        #layers.experimental.preprocessing.randomzoom(),
        #layers.experimental.preprocessing.RandomRotation(0),
        #layers.experimental.preprocessing.RandomRotation(0),

# %%
# visualize the augmentation
plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i+1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %%
# Preprocessing 
augmented_train_dataset = train_dataset.map(
  lambda x, y: (data_augmentation(x, training=True), y)
  )

# %%
# Configure the dataset for performance
train_dataset = train_dataset.prefetch(buffer_size=32)
val_dataset   = val_dataset.prefetch(buffer_size=32)

# %%
# CNN model
def make_model(input_shape, num_classes):
    inputs = K.Input(shape=input_shape)
    # Image augmentation block
    x = data_augmentation(inputs)
    # data preprocessing - rescale
    x = layers.experimental.preprocessing.Rescaling(1.0 / 255)(x)
    # padding
    x = layers.Conv2D(32, 3, strides=2, padding="same")(x)
    # batch norm
    x = layers.BatchNormalization()(x)
    # activate for the first layer
    x = layers.Activation("relu")(x)

    x = layers.Conv2D(64, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    """
    #model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
    x = layers.SeparableConv2D(128, 3, padding="same")(x)  
    #model.add(layers.MaxPooling2D((2, 2)))
    x = layers.MaxPooling2D(3, strides=2, padding="same")(x)
    #model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    x = layers.SeparableConv2D(256, 3, padding="same")(x)
    #model.add(layers.MaxPooling2D((2, 2)))
    x = layers.MaxPooling2D(3, strides=2, padding="same")(x)
    #model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    x = layers.SeparableConv2D(512, 3, padding="same")(x)

    """ 
    for size in [128, 256, 512, 728]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(size, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual
    
    # last layer
    x = layers.SeparableConv2D(1024, 3, padding="same")(x)
    #x = layers.SeparableConv2D(512, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.GlobalAveragePooling2D()(x)

    # activation function test:
    # sigmoid, softmax: advantages
    print("num_classes=", num_classes)
    if num_classes == 2:
        activation = "sigmoid"
        units = 1
    else:
        activation = "softmax"
        units = num_classes
    
    # since the amount of images is not so much, 
    # to avoid obvious changes, dropout is 0.25 instead of 0.5
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(units, activation=activation)(x)
    return K.Model(inputs, outputs)


model = make_model(input_shape=image_size + (3,), num_classes=2)
K.utils.plot_model(model, show_shapes=True)
# Out:
# num_classes= 2

# %%
# train the model

callbacks = [
    K.callbacks.ModelCheckpoint("save_at_{epoch}.h5"),
]
model.compile(
    optimizer=K.optimizers.Adam(1e-3),
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
tic = time.perf_counter()

# train model
history = model.fit(
    train_dataset, epochs=epochs, callbacks=callbacks, validation_data=val_dataset,
)

toc = time.perf_counter()

# Time needed to train the model
trainTime = (toc-tic)*1000
trainTimeShort = np.trunc(trainTime)
print("Training time = " + str(trainTimeShort) +"ms")
# Out:
# Epoch 1/100
# 13/13 [==============================] - 59s 3s/step - loss: 0.5023 - accuracy: 0.7650 - val_loss: 0.6938 - val_accuracy: 0.4900
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/100
# 13/13 [==============================] - 2s 129ms/step - loss: 0.2069 - accuracy: 0.9375 - val_loss: 0.6993 - val_accuracy: 0.4900
# Epoch 3/100
# 13/13 [==============================] - 2s 129ms/step - loss: 0.0796 - accuracy: 0.9900 - val_loss: 0.7119 - val_accuracy: 0.4900
# Epoch 4/100
# 13/13 [==============================] - 2s 128ms/step - loss: 0.0396 - accuracy: 0.9925 - val_loss: 0.7326 - val_accuracy: 0.4900
# Epoch 5/100
# 13/13 [==============================] - 2s 131ms/step - loss: 0.0186 - accuracy: 0.9975 - val_loss: 0.7574 - val_accuracy: 0.4900
# Epoch 6/100
# 13/13 [==============================] - 2s 130ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.7835 - val_accuracy: 0.4900
# Epoch 7/100
# 13/13 [==============================] - 2s 129ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.8234 - val_accuracy: 0.4900
# Epoch 8/100
# 13/13 [==============================] - 2s 128ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.8329 - val_accuracy: 0.4900
# Epoch 9/100
# 13/13 [==============================] - 2s 129ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.8602 - val_accuracy: 0.4900
# Epoch 10/100
# 13/13 [==============================] - 2s 129ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.8741 - val_accuracy: 0.4900
# Epoch 11/100
# 13/13 [==============================] - 2s 129ms/step - loss: 7.7276e-04 - accuracy: 1.0000 - val_loss: 0.8961 - val_accuracy: 0.4900
# Epoch 12/100
# 13/13 [==============================] - 2s 129ms/step - loss: 9.0939e-04 - accuracy: 1.0000 - val_loss: 0.9062 - val_accuracy: 0.4900
# Epoch 13/100
# 13/13 [==============================] - 2s 129ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.9254 - val_accuracy: 0.4900
# Epoch 14/100
# 13/13 [==============================] - 2s 130ms/step - loss: 9.3728e-04 - accuracy: 1.0000 - val_loss: 0.9505 - val_accuracy: 0.4900
# Epoch 15/100
# 13/13 [==============================] - 2s 130ms/step - loss: 7.1009e-04 - accuracy: 1.0000 - val_loss: 0.9755 - val_accuracy: 0.4900
# Epoch 16/100
# 13/13 [==============================] - 2s 131ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.0022 - val_accuracy: 0.4900
# Epoch 17/100
# 13/13 [==============================] - 2s 130ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.0537 - val_accuracy: 0.4900
# Epoch 18/100
# 13/13 [==============================] - 2s 130ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.0644 - val_accuracy: 0.4900
# Epoch 19/100
# 13/13 [==============================] - 2s 130ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 1.1438 - val_accuracy: 0.4900
# Epoch 20/100
# 13/13 [==============================] - 2s 129ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 1.0880 - val_accuracy: 0.4900
# Epoch 21/100
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.1599 - val_accuracy: 0.4900
# Epoch 22/100
# 13/13 [==============================] - 2s 130ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.1461 - val_accuracy: 0.4900
# Epoch 23/100
# 13/13 [==============================] - 2s 131ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.3049 - val_accuracy: 0.4900
# Epoch 24/100
# 13/13 [==============================] - 2s 130ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.2143 - val_accuracy: 0.4900
# Epoch 25/100
# 13/13 [==============================] - 2s 129ms/step - loss: 7.3534e-04 - accuracy: 1.0000 - val_loss: 1.2866 - val_accuracy: 0.4900
# Epoch 26/100
# 13/13 [==============================] - 2s 130ms/step - loss: 3.0187e-04 - accuracy: 1.0000 - val_loss: 1.2839 - val_accuracy: 0.4900
# Epoch 27/100
# 13/13 [==============================] - 2s 131ms/step - loss: 4.6512e-04 - accuracy: 1.0000 - val_loss: 1.2397 - val_accuracy: 0.4900
# Epoch 28/100
# 13/13 [==============================] - 2s 129ms/step - loss: 1.8082e-04 - accuracy: 1.0000 - val_loss: 1.3036 - val_accuracy: 0.4900
# Epoch 29/100
# 13/13 [==============================] - 2s 133ms/step - loss: 2.7672e-04 - accuracy: 1.0000 - val_loss: 1.4033 - val_accuracy: 0.4900
# Epoch 30/100
# 13/13 [==============================] - 2s 131ms/step - loss: 6.3927e-04 - accuracy: 1.0000 - val_loss: 1.4695 - val_accuracy: 0.4900
# Epoch 31/100
# 13/13 [==============================] - 2s 132ms/step - loss: 6.2582e-04 - accuracy: 1.0000 - val_loss: 1.6401 - val_accuracy: 0.4900
# Epoch 32/100
# 13/13 [==============================] - 2s 129ms/step - loss: 3.8852e-04 - accuracy: 1.0000 - val_loss: 1.7408 - val_accuracy: 0.4900
# Epoch 33/100
# 13/13 [==============================] - 2s 129ms/step - loss: 2.9979e-04 - accuracy: 1.0000 - val_loss: 2.0586 - val_accuracy: 0.4900
# Epoch 34/100
# 13/13 [==============================] - 2s 131ms/step - loss: 2.1757e-04 - accuracy: 1.0000 - val_loss: 2.5364 - val_accuracy: 0.4900
# Epoch 35/100
# 13/13 [==============================] - 2s 132ms/step - loss: 1.6830e-04 - accuracy: 1.0000 - val_loss: 2.6315 - val_accuracy: 0.4900
# Epoch 36/100
# 13/13 [==============================] - 2s 131ms/step - loss: 1.4329e-04 - accuracy: 1.0000 - val_loss: 2.7182 - val_accuracy: 0.4900
# Epoch 37/100
# 13/13 [==============================] - 2s 131ms/step - loss: 9.6632e-05 - accuracy: 1.0000 - val_loss: 2.8985 - val_accuracy: 0.4900
# Epoch 38/100
# 13/13 [==============================] - 2s 129ms/step - loss: 1.1534e-04 - accuracy: 1.0000 - val_loss: 3.1805 - val_accuracy: 0.4900
# Epoch 39/100
# 13/13 [==============================] - 2s 128ms/step - loss: 1.1713e-04 - accuracy: 1.0000 - val_loss: 3.2899 - val_accuracy: 0.4900
# Epoch 40/100
# 13/13 [==============================] - 2s 132ms/step - loss: 1.3876e-04 - accuracy: 1.0000 - val_loss: 3.0766 - val_accuracy: 0.4900
# Epoch 41/100
# 13/13 [==============================] - 2s 132ms/step - loss: 5.7287e-05 - accuracy: 1.0000 - val_loss: 3.0737 - val_accuracy: 0.4900
# Epoch 42/100
# 13/13 [==============================] - 2s 128ms/step - loss: 5.4885e-05 - accuracy: 1.0000 - val_loss: 3.0349 - val_accuracy: 0.4900
# Epoch 43/100
# 13/13 [==============================] - 2s 132ms/step - loss: 9.0969e-05 - accuracy: 1.0000 - val_loss: 2.9914 - val_accuracy: 0.4900
# Epoch 44/100
# 13/13 [==============================] - 2s 130ms/step - loss: 1.1680e-04 - accuracy: 1.0000 - val_loss: 2.7878 - val_accuracy: 0.4900
# Epoch 45/100
# 13/13 [==============================] - 2s 130ms/step - loss: 7.0743e-05 - accuracy: 1.0000 - val_loss: 2.5653 - val_accuracy: 0.4900
# Epoch 46/100
# 13/13 [==============================] - 2s 131ms/step - loss: 1.2470e-04 - accuracy: 1.0000 - val_loss: 2.2920 - val_accuracy: 0.4900
# Epoch 47/100
# 13/13 [==============================] - 2s 129ms/step - loss: 6.2273e-05 - accuracy: 1.0000 - val_loss: 1.7945 - val_accuracy: 0.4900
# Epoch 48/100
# 13/13 [==============================] - 2s 130ms/step - loss: 1.1127e-04 - accuracy: 1.0000 - val_loss: 1.1996 - val_accuracy: 0.4900
# Epoch 49/100
# 13/13 [==============================] - 2s 131ms/step - loss: 1.2799e-04 - accuracy: 1.0000 - val_loss: 1.2548 - val_accuracy: 0.4900
# Epoch 50/100
# 13/13 [==============================] - 2s 129ms/step - loss: 2.2175e-04 - accuracy: 1.0000 - val_loss: 0.8304 - val_accuracy: 0.5100
# Epoch 51/100
# 13/13 [==============================] - 2s 129ms/step - loss: 8.7984e-05 - accuracy: 1.0000 - val_loss: 0.4628 - val_accuracy: 0.6900
# Epoch 52/100
# 13/13 [==============================] - 2s 129ms/step - loss: 2.9921e-04 - accuracy: 1.0000 - val_loss: 0.1083 - val_accuracy: 1.0000
# Epoch 53/100
# 13/13 [==============================] - 2s 131ms/step - loss: 1.0226e-04 - accuracy: 1.0000 - val_loss: 0.0448 - val_accuracy: 1.0000
# Epoch 54/100
# 13/13 [==============================] - 2s 130ms/step - loss: 7.7742e-05 - accuracy: 1.0000 - val_loss: 0.0244 - val_accuracy: 1.0000
# Epoch 55/100
# 13/13 [==============================] - 2s 129ms/step - loss: 5.7870e-05 - accuracy: 1.0000 - val_loss: 0.0175 - val_accuracy: 1.0000
# Epoch 56/100
# 13/13 [==============================] - 2s 132ms/step - loss: 5.5719e-05 - accuracy: 1.0000 - val_loss: 0.0089 - val_accuracy: 1.0000
# Epoch 57/100
# 13/13 [==============================] - 2s 131ms/step - loss: 6.2437e-05 - accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 58/100
# 13/13 [==============================] - 2s 131ms/step - loss: 1.3236e-04 - accuracy: 1.0000 - val_loss: 4.8571e-04 - val_accuracy: 1.0000
# Epoch 59/100
# 13/13 [==============================] - 2s 131ms/step - loss: 1.1333e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 60/100
# 13/13 [==============================] - 2s 130ms/step - loss: 1.9395e-04 - accuracy: 1.0000 - val_loss: 7.5373e-04 - val_accuracy: 1.0000
# Epoch 61/100
# 13/13 [==============================] - 2s 132ms/step - loss: 6.0376e-05 - accuracy: 1.0000 - val_loss: 7.8772e-04 - val_accuracy: 1.0000
# Epoch 62/100
# 13/13 [==============================] - 2s 133ms/step - loss: 1.8122e-04 - accuracy: 1.0000 - val_loss: 6.6878e-05 - val_accuracy: 1.0000
# Epoch 63/100
# 13/13 [==============================] - 2s 131ms/step - loss: 7.0035e-05 - accuracy: 1.0000 - val_loss: 3.4872e-04 - val_accuracy: 1.0000
# Epoch 64/100
# 13/13 [==============================] - 2s 137ms/step - loss: 4.7196e-04 - accuracy: 1.0000 - val_loss: 1.4681e-04 - val_accuracy: 1.0000
# Epoch 65/100
# 13/13 [==============================] - 2s 132ms/step - loss: 3.7392e-05 - accuracy: 1.0000 - val_loss: 1.5057e-05 - val_accuracy: 1.0000
# Epoch 66/100
# 13/13 [==============================] - 2s 130ms/step - loss: 3.5284e-04 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 67/100
# 13/13 [==============================] - 2s 133ms/step - loss: 4.7063e-04 - accuracy: 1.0000 - val_loss: 5.1098e-05 - val_accuracy: 1.0000
# Epoch 68/100
# 13/13 [==============================] - 2s 131ms/step - loss: 2.6724e-04 - accuracy: 1.0000 - val_loss: 7.9505e-05 - val_accuracy: 1.0000
# Epoch 69/100
# 13/13 [==============================] - 2s 130ms/step - loss: 1.6594e-04 - accuracy: 1.0000 - val_loss: 3.4529e-04 - val_accuracy: 1.0000
# Epoch 70/100
# 13/13 [==============================] - 2s 135ms/step - loss: 1.2627e-04 - accuracy: 1.0000 - val_loss: 7.9983e-05 - val_accuracy: 1.0000
# Epoch 71/100
# 13/13 [==============================] - 2s 132ms/step - loss: 8.5229e-05 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 72/100
# 13/13 [==============================] - 2s 140ms/step - loss: 7.6997e-05 - accuracy: 1.0000 - val_loss: 9.9117e-05 - val_accuracy: 1.0000
# Epoch 73/100
# 13/13 [==============================] - 2s 131ms/step - loss: 5.1431e-05 - accuracy: 1.0000 - val_loss: 1.7169e-05 - val_accuracy: 1.0000
# Epoch 74/100
# 13/13 [==============================] - 2s 132ms/step - loss: 4.9047e-05 - accuracy: 1.0000 - val_loss: 8.8068e-06 - val_accuracy: 1.0000
# Epoch 75/100
# 13/13 [==============================] - 2s 133ms/step - loss: 4.7272e-05 - accuracy: 1.0000 - val_loss: 7.5164e-06 - val_accuracy: 1.0000
# Epoch 76/100
# 13/13 [==============================] - 2s 134ms/step - loss: 4.6097e-05 - accuracy: 1.0000 - val_loss: 8.4970e-06 - val_accuracy: 1.0000
# Epoch 77/100
# 13/13 [==============================] - 2s 129ms/step - loss: 3.3187e-05 - accuracy: 1.0000 - val_loss: 7.7799e-06 - val_accuracy: 1.0000
# Epoch 78/100
# 13/13 [==============================] - 2s 134ms/step - loss: 1.2244e-04 - accuracy: 1.0000 - val_loss: 1.4865e-05 - val_accuracy: 1.0000
# Epoch 79/100
# 13/13 [==============================] - 2s 131ms/step - loss: 5.0218e-05 - accuracy: 1.0000 - val_loss: 1.8499e-05 - val_accuracy: 1.0000
# Epoch 80/100
# 13/13 [==============================] - 2s 133ms/step - loss: 7.4937e-05 - accuracy: 1.0000 - val_loss: 8.1695e-06 - val_accuracy: 1.0000
# Epoch 81/100
# 13/13 [==============================] - 2s 130ms/step - loss: 1.3451e-04 - accuracy: 1.0000 - val_loss: 1.1092e-05 - val_accuracy: 1.0000
# Epoch 82/100
# 13/13 [==============================] - 2s 128ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 1.0000
# Epoch 83/100
# 13/13 [==============================] - 2s 129ms/step - loss: 6.3979e-04 - accuracy: 1.0000 - val_loss: 0.0865 - val_accuracy: 0.9600
# Epoch 84/100
# 13/13 [==============================] - 2s 130ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.9679 - val_accuracy: 0.7000
# Epoch 85/100
# 13/13 [==============================] - 2s 131ms/step - loss: 0.1856 - accuracy: 0.9225 - val_loss: 58.3448 - val_accuracy: 0.5100
# Epoch 86/100
# 13/13 [==============================] - 2s 130ms/step - loss: 0.1588 - accuracy: 0.9375 - val_loss: 2.1266 - val_accuracy: 0.8000
# Epoch 87/100
# 13/13 [==============================] - 2s 130ms/step - loss: 0.0500 - accuracy: 0.9925 - val_loss: 178.9134 - val_accuracy: 0.5100
# Epoch 88/100
# 13/13 [==============================] - 2s 130ms/step - loss: 0.0252 - accuracy: 0.9975 - val_loss: 95.8712 - val_accuracy: 0.5100
# Epoch 89/100
# 13/13 [==============================] - 2s 130ms/step - loss: 0.0482 - accuracy: 0.9850 - val_loss: 18.7515 - val_accuracy: 0.5100
# Epoch 90/100
# 13/13 [==============================] - 2s 131ms/step - loss: 0.0884 - accuracy: 0.9675 - val_loss: 3.7937 - val_accuracy: 0.6300
# Epoch 91/100
# 13/13 [==============================] - 2s 131ms/step - loss: 0.0237 - accuracy: 0.9950 - val_loss: 11.1813 - val_accuracy: 0.5100
# Epoch 92/100
# 13/13 [==============================] - 2s 131ms/step - loss: 0.0478 - accuracy: 0.9875 - val_loss: 0.8940 - val_accuracy: 0.8400
# Epoch 93/100
# 13/13 [==============================] - 2s 130ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 12.0837 - val_accuracy: 0.5100
# Epoch 94/100
# 13/13 [==============================] - 2s 132ms/step - loss: 0.0090 - accuracy: 0.9975 - val_loss: 9.2918 - val_accuracy: 0.4900
# Epoch 95/100
# 13/13 [==============================] - 2s 132ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 1.0252e-04 - val_accuracy: 1.0000
# Epoch 96/100
# 13/13 [==============================] - 2s 130ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 97/100
# 13/13 [==============================] - 2s 131ms/step - loss: 9.3745e-04 - accuracy: 1.0000 - val_loss: 7.4579e-05 - val_accuracy: 1.0000
# Epoch 98/100
# 13/13 [==============================] - 2s 133ms/step - loss: 3.8613e-04 - accuracy: 1.0000 - val_loss: 2.1780e-04 - val_accuracy: 1.0000
# Epoch 99/100
# 13/13 [==============================] - 2s 131ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0218 - val_accuracy: 1.0000
# Epoch 100/100
# 13/13 [==============================] - 2s 131ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 1.0000
# Training time = 359842.0ms

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1.1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(images,  labels, verbose=2)
# Out:
# 1/1 - 0s - loss: 5.4419 - accuracy: 0.5312

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 10])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(images,  labels, verbose=2)
# Out:
# 1/1 - 0s - loss: 5.4419 - accuracy: 0.5312

# %%
# 1. Predict new images
img = K.preprocessing.image.load_img(
    "WrinkleImages2/bad/83.jpg",  #65, 6,16,21,30,41, 71, 83
    #"WrinkleImages2/good/100.jpg",  # 9,27,67,114
    #"WrinkleImagesTest/aug4.jpg",
    target_size=image_size
)
tic = time.perf_counter()
img_array = K.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis
predictions = model.predict(img_array)
toc = time.perf_counter()

# 2. Evaluate the prediction run time
predictTime = (toc-tic)*1000
predictTimeShort = np.trunc(predictTime)
print("Predict time = " + str(predictTimeShort) +"ms")

# 3. Prediction result
score = predictions[0]
print(
    "This image is %.2f percent bad and %.2f percent good."
    % (100 * (1 - score), 100 * score)
)

# 4. Display prediction image
plt.imshow(img)
# Out:
# Predict time = 300.0ms
# This image is 0.61 percent bad and 99.39 percent good.
